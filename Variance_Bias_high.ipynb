# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("onlinefoods.csv")
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
data = df

# %%
data = data.drop(['Marital Status','Educational Qualifications','latitude','longitude','Output','Unnamed: 12'],axis =1 )
data
# Out:
#      Age  Gender Occupation  Monthly Income  Family size  Pin code   Feedback
# 0     20  Female    Student       No Income            4    560001   Positive
# 1     24  Female    Student  Below Rs.10000            3    560009   Positive
# 2     22    Male    Student  Below Rs.10000            3    560017  Negative
# 3     22  Female    Student       No Income            6    560019   Positive
# 4     22    Male    Student  Below Rs.10000            4    560010   Positive
# ..   ...     ...        ...             ...          ...       ...        ...
# 383   23  Female    Student       No Income            2    560001   Positive
# 384   23  Female    Student       No Income            4    560048   Positive
# 385   22  Female    Student       No Income            5    560010   Positive
# 386   23    Male    Student  Below Rs.10000            2    560009   Positive
# 387   23    Male    Student       No Income            5    560078   Positive
#
# [388 rows x 7 columns]

# %%
# Encoder
label_encoder = preprocessing.LabelEncoder()
data['Feedback'] = label_encoder.fit_transform(data['Feedback'])
data['Feedback'].unique()
data
# Out:
#      Age  Gender Occupation  Monthly Income  Family size  Pin code  Feedback
# 0     20  Female    Student       No Income            4    560001         1
# 1     24  Female    Student  Below Rs.10000            3    560009         1
# 2     22    Male    Student  Below Rs.10000            3    560017         0
# 3     22  Female    Student       No Income            6    560019         1
# 4     22    Male    Student  Below Rs.10000            4    560010         1
# ..   ...     ...        ...             ...          ...       ...       ...
# 383   23  Female    Student       No Income            2    560001         1
# 384   23  Female    Student       No Income            4    560048         1
# 385   22  Female    Student       No Income            5    560010         1
# 386   23    Male    Student  Below Rs.10000            2    560009         1
# 387   23    Male    Student       No Income            5    560078         1
#
# [388 rows x 7 columns]

# %%
label_encoder = preprocessing.LabelEncoder()
data['Gender'] = label_encoder.fit_transform(data['Gender'])
data['Gender'].unique()
data
# Out:
#      Age  Gender Occupation  Monthly Income  Family size  Pin code  Feedback
# 0     20       0    Student       No Income            4    560001         1
# 1     24       0    Student  Below Rs.10000            3    560009         1
# 2     22       1    Student  Below Rs.10000            3    560017         0
# 3     22       0    Student       No Income            6    560019         1
# 4     22       1    Student  Below Rs.10000            4    560010         1
# ..   ...     ...        ...             ...          ...       ...       ...
# 383   23       0    Student       No Income            2    560001         1
# 384   23       0    Student       No Income            4    560048         1
# 385   22       0    Student       No Income            5    560010         1
# 386   23       1    Student  Below Rs.10000            2    560009         1
# 387   23       1    Student       No Income            5    560078         1
#
# [388 rows x 7 columns]

# %%
label_encoder = preprocessing.LabelEncoder()
data['Monthly Income'] = label_encoder.fit_transform(data['Monthly Income'])
data['Monthly Income'].unique()
data
# Out:
#      Age  Gender Occupation  Monthly Income  Family size  Pin code  Feedback
# 0     20       0    Student               4            4    560001         1
# 1     24       0    Student               2            3    560009         1
# 2     22       1    Student               2            3    560017         0
# 3     22       0    Student               4            6    560019         1
# 4     22       1    Student               2            4    560010         1
# ..   ...     ...        ...             ...          ...       ...       ...
# 383   23       0    Student               4            2    560001         1
# 384   23       0    Student               4            4    560048         1
# 385   22       0    Student               4            5    560010         1
# 386   23       1    Student               2            2    560009         1
# 387   23       1    Student               4            5    560078         1
#
# [388 rows x 7 columns]

# %%
label_encoder = preprocessing.LabelEncoder()
data['Occupation'] = label_encoder.fit_transform(data['Occupation'])
data['Occupation'].unique()
data
# Out:
#      Age  Gender  Occupation  Monthly Income  Family size  Pin code  Feedback
# 0     20       0           3               4            4    560001         1
# 1     24       0           3               2            3    560009         1
# 2     22       1           3               2            3    560017         0
# 3     22       0           3               4            6    560019         1
# 4     22       1           3               2            4    560010         1
# ..   ...     ...         ...             ...          ...       ...       ...
# 383   23       0           3               4            2    560001         1
# 384   23       0           3               4            4    560048         1
# 385   22       0           3               4            5    560010         1
# 386   23       1           3               2            2    560009         1
# 387   23       1           3               4            5    560078         1
#
# [388 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# Age               0
# Gender            0
# Occupation        0
# Monthly Income    0
# Family size       0
# Pin code          0
# Feedback          0
# dtype: int64

# %%
y = data["Feedback"]
data = data.drop('Feedback',axis=1)
data
# Out:
#      Age  Gender  Occupation  Monthly Income  Family size  Pin code
# 0     20       0           3               4            4    560001
# 1     24       0           3               2            3    560009
# 2     22       1           3               2            3    560017
# 3     22       0           3               4            6    560019
# 4     22       1           3               2            4    560010
# ..   ...     ...         ...             ...          ...       ...
# 383   23       0           3               4            2    560001
# 384   23       0           3               4            4    560048
# 385   22       0           3               4            5    560010
# 386   23       1           3               2            2    560009
# 387   23       1           3               4            5    560078
#
# [388 rows x 6 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 383    1
# 384    1
# 385    1
# 386    1
# 387    1
# Name: Feedback, Length: 388, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(data,y,test_size=0.2,random_state=0)

model= LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
pred
# Out:
# array([0.92116118, 0.8292203 , 0.73161359, 0.76416828, 0.91329562,
#        0.88355749, 0.83016371, 0.96413972, 0.72724848, 0.9720941 ,
#        0.67973447, 0.77120453, 0.71891071, 0.66305588, 0.84424167,
#        0.88412424, 0.92125915, 0.7747696 , 0.83542588, 0.84359297,
#        0.8427749 , 0.88418724, 0.63173191, 0.83825767, 0.83224737,
#        0.93977186, 0.79127189, 0.6669669 , 0.72138721, 0.68859906,
#        0.78834432, 0.67709887, 0.90305771, 0.91233155, 0.87630558,
#        0.80032129, 0.91233155, 0.69522579, 0.79765933, 0.81780592,
#        0.77511934, 0.92355697, 0.97563533, 0.94079435, 0.96440256,
#        0.66785585, 0.88339956, 0.96866846, 0.68408743, 0.86486382,
#        0.84713421, 0.95375541, 0.65430874, 0.66305588, 0.83016371,
#        0.8187809 , 0.84182236, 0.90408477, 0.75404037, 0.93266137,
#        0.84496628, 0.63173191, 0.68892643, 0.83460651, 0.84359297,
#        0.78884477, 0.74841259, 0.74477847, 0.91732061, 0.72403941,
# ...

# %%
pred1 = model.predict(x_train)
pred1
# Out:
# array([0.71662958, 0.93398083, 0.8848009 , 0.96967943, 1.00025908,
#        0.95172195, 0.78884477, 0.94079435, 0.61799647, 0.88319515,
#        0.67709887, 0.65430874, 0.86781484, 0.9009643 , 0.92765344,
#        0.95172195, 0.83016371, 0.60340206, 0.93228015, 0.90132207,
#        0.79674051, 0.83468309, 0.86326264, 0.77222093, 0.6424822 ,
#        0.78573049, 0.86486382, 0.88809081, 0.75610871, 0.90305771,
#        0.64962308, 0.69649939, 0.9429273 , 0.93266137, 0.94391482,
#        0.95754796, 0.92125915, 0.76858489, 0.7447103 , 0.69158608,
#        0.73383528, 0.88003971, 0.92355697, 0.86090182, 0.80405084,
#        0.82674606, 0.74273587, 0.94283754, 0.9003741 , 0.88418724,
#        0.81780592, 0.92355697, 0.79800287, 0.67325475, 0.89241057,
#        0.88165697, 0.77174012, 0.88809081, 0.87297334, 0.79582371,
#        0.79765933, 0.80913444, 0.85696328, 0.96449748, 0.63125576,
#        0.6960226 , 0.83776135, 0.85994928, 0.87630558, 0.69768458,
# ...

# %%
# finding variance using np
variance = np.var(pred)
variance
# Out:
# 0.009172657679681433

# %%
SSE = np.mean((np.mean(pred1)-y)**2)
Bias = SSE-variance
Bias
# Out:
# 0.14033258278074967

# %%
p1 = np.polyfit(pred1,pred,1)
plt.scatter(pred1,pred)
plt.plot(np.polyval(p1,pred1),c='r')
